# %% [markdown]
# <a href="https://colab.research.google.com/github/oolyvenubs-pixel/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1

name = input("Name: ")
age = input("Age: ")
course = input("Course: ")

print("Name:", name)
print("Age:", age)
print("Course:", course)

# %%
#fa3prog2

score = float(input("Enter exam score: "))


if score >= 75:
  print("Passed")
else:
  print("Failed")

# %%
#fa3prog3


score = int(input("Score: "))

if score >= 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
else:
  print("F")
# Out:
# Score: 78
# C
